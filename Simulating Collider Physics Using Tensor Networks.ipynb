# %%
using ITensors, ITensorMPS, Plots
using Plots.PlotMeasures

# %%
N = 51 #Number of lattice sites per dimension
d = 1 #Number of spatial dimensions
dx = 1 #Lattice spacing

n_0 = round(Int, ((N-1)/2)) #Index of thepoint at the center of the lattice.
dp = (2*pi)/(N*dx) #Discrete change in momentum
p_i = range(1/2*dp, stop = dp*(N+1/2), length = (N+1))[1:end-1]

om_i = Float64[] #List of omega values for each lattice site (eq. 12)
for i in 1:N
    push!(om_i, (2/dx)*abs(sin(p_i[i]*dx/2)))
end

# %%
H = OpSum() #Evaluate the sum of the pi^2 and phi operators that make up the Hamiltonian
for i in 1:N
    H += (om_i[i]*dp)/(2pi), "a", i, "a†", i
    H += (om_i[i]*dp)/(2pi)*(1/2)*(2pi/dp), "Id", i
end

sites = siteinds("Boson", N; dim=9) #Create ITensor "SFT" sites
# Out:
# 51-element Vector{Index{Int64}}:
#  (dim=9|id=996|"Boson,Site,n=1")
#  (dim=9|id=832|"Boson,Site,n=2")
#  (dim=9|id=452|"Boson,Site,n=3")
#  (dim=9|id=228|"Boson,Site,n=4")
#  (dim=9|id=999|"Boson,Site,n=5")
#  (dim=9|id=86|"Boson,Site,n=6")
#  (dim=9|id=307|"Boson,Site,n=7")
#  (dim=9|id=347|"Boson,Site,n=8")
#  (dim=9|id=924|"Boson,Site,n=9")
#  (dim=9|id=902|"Boson,Site,n=10")
#  (dim=9|id=833|"Boson,Site,n=11")
#  (dim=9|id=256|"Boson,Site,n=12")
#  (dim=9|id=163|"Boson,Site,n=13")
#  ⋮
#  (dim=9|id=581|"Boson,Site,n=40")
#  (dim=9|id=296|"Boson,Site,n=41")
#  (dim=9|id=252|"Boson,Site,n=42")
#  (dim=9|id=809|"Boson,Site,n=43")
#  (dim=9|id=891|"Boson,Site,n=44")
#  (dim=9|id=145|"Boson,Site,n=45")
#  (dim=9|id=680|"Boson,Site,n=46")
#  (dim=9|id=221|"Boson,Site,n=47")
#  (dim=9|id=905|"Boson,Site,n=48")
#  (dim=9|id=25|"Boson,Site,n=49")
#  (dim=9|id=733|"Boson,Site,n=50")
#  (dim=9|id=484|"Boson,Site,n=51")

# %%
function MakeState(excitation_dict)
    for i in keys(excitation_dict)
        if i > N
            error("excitation_dict contains an index that is greater than the number of sites in the lattice.")
        end
    end

    state = []
    for i in 1:N
        if haskey(excitation_dict, i)
            push!(state, excitation_dict[i])
        else
            push!(state, "0")
        end
    end

    return state
end
# Out:
# MakeState (generic function with 1 method)

# %%
gs_Dict = Dict() #Dictionary containing excitations (or lack thereof) in the ground state
s1_Dict = Dict(1=>"1") #Dictionary containing excitations in the arbitrary state, State 1
s2_Dict = Dict(1=>"1", N=>"1") #Dictionary containing excitations in the arbitrary state, State 2

psi_gs = MPS(sites, MakeState(gs_Dict)) #Ground State
psi_p1 = MPS(sites, MakeState(s1_Dict)) #State 1
psi_p1p2 = MPS(sites, MakeState(s2_Dict)) #State 2
# Out:
# MPS
# [1] ((dim=9|id=996|"Boson,Site,n=1"), (dim=1|id=530|"Link,l=1"))
# [2] ((dim=1|id=530|"Link,l=1"), (dim=9|id=832|"Boson,Site,n=2"), (dim=1|id=166|"Link,l=2"))
# [3] ((dim=1|id=166|"Link,l=2"), (dim=9|id=452|"Boson,Site,n=3"), (dim=1|id=974|"Link,l=3"))
# [4] ((dim=1|id=974|"Link,l=3"), (dim=9|id=228|"Boson,Site,n=4"), (dim=1|id=76|"Link,l=4"))
# [5] ((dim=1|id=76|"Link,l=4"), (dim=9|id=999|"Boson,Site,n=5"), (dim=1|id=967|"Link,l=5"))
# [6] ((dim=1|id=967|"Link,l=5"), (dim=9|id=86|"Boson,Site,n=6"), (dim=1|id=300|"Link,l=6"))
# [7] ((dim=1|id=300|"Link,l=6"), (dim=9|id=307|"Boson,Site,n=7"), (dim=1|id=934|"Link,l=7"))
# [8] ((dim=1|id=934|"Link,l=7"), (dim=9|id=347|"Boson,Site,n=8"), (dim=1|id=692|"Link,l=8"))
# [9] ((dim=1|id=692|"Link,l=8"), (dim=9|id=924|"Boson,Site,n=9"), (dim=1|id=593|"Link,l=9"))
# [10] ((dim=1|id=593|"Link,l=9"), (dim=9|id=902|"Boson,Site,n=10"), (dim=1|id=962|"Link,l=10"))
# [11] ((dim=1|id=962|"Link,l=10"), (dim=9|id=833|"Boson,Site,n=11"), (dim=1|id=652|"Link,l=11"))
# [12] ((dim=1|id=652|"Link,l=11"), (dim=9|id=256|"Boson,Site,n=12"), (dim=1|id=589|"Link,l=12"))
# [13] ((dim=1|id=589|"Link,l=12"), (dim=9|id=163|"Boson,Site,n=13"), (dim=1|id=401|"Link,l=13"))
# [14] ((dim=1|id=401|"Link,l=13"), (dim=9|id=319|"Boson,Site,n=14"), (dim=1|id=746|"Link,l=14"))
# [15] ((dim=1|id=746|"Link,l=14"), (dim=9|id=539|"Boson,Site,n=15"), (dim=1|id=756|"Link,l=15"))
# [16] ((dim=1|id=756|"Link,l=15"), (dim=9|id=965|"Boson,Site,n=16"), (dim=1|id=410|"Link,l=16"))
# [17] ((dim=1|id=410|"Link,l=16"), (dim=9|id=578|"Boson,Site,n=17"), (dim=1|id=660|"Link,l=17"))
# [18] ((dim=1|id=660|"Link,l=17"), (dim=9|id=199|"Boson,Site,n=18"), (dim=1|id=360|"Link,l=18"))
# [19] ((dim=1|id=360|"Link,l=18"), (dim=9|id=613|"Boson,Site,n=19"), (dim=1|id=127|"Link,l=19"))
# [20] ((dim=1|id=127|"Link,l=19"), (dim=9|id=807|"Boson,Site,n=20"), (dim=1|id=138|"Link,l=20"))
# [21] ((dim=1|id=138|"Link,l=20"), (dim=9|id=554|"Boson,Site,n=21"), (dim=1|id=34|"Link,l=21"))
# [22] ((dim=1|id=34|"Link,l=21"), (dim=9|id=123|"Boson,Site,n=22"), (dim=1|id=402|"Link,l=22"))
# [23] ((dim=1|id=402|"Link,l=22"), (dim=9|id=836|"Boson,Site,n=23"), (dim=1|id=479|"Link,l=23"))
# [24] ((dim=1|id=479|"Link,l=23"), (dim=9|id=547|"Boson,Site,n=24"), (dim=1|id=596|"Link,l=24"))
# [25] ((dim=1|id=596|"Link,l=24"), (dim=9|id=998|"Boson,Site,n=25"), (dim=1|id=256|"Link,l=25"))
# [26] ((dim=1|id=256|"Link,l=25"), (dim=9|id=806|"Boson,Site,n=26"), (dim=1|id=681|"Link,l=26"))
# [27] ((dim=1|id=681|"Link,l=26"), (dim=9|id=616|"Boson,Site,n=27"), (dim=1|id=870|"Link,l=27"))
# [28] ((dim=1|id=870|"Link,l=27"), (dim=9|id=771|"Boson,Site,n=28"), (dim=1|id=772|"Link,l=28"))
# [29] ((dim=1|id=772|"Link,l=28"), (dim=9|id=137|"Boson,Site,n=29"), (dim=1|id=625|"Link,l=29"))
# [30] ((dim=1|id=625|"Link,l=29"), (dim=9|id=153|"Boson,Site,n=30"), (dim=1|id=323|"Link,l=30"))
# [31] ((dim=1|id=323|"Link,l=30"), (dim=9|id=564|"Boson,Site,n=31"), (dim=1|id=59|"Link,l=31"))
# [32] ((dim=1|id=59|"Link,l=31"), (dim=9|id=814|"Boson,Site,n=32"), (dim=1|id=14|"Link,l=32"))
# [33] ((dim=1|id=14|"Link,l=32"), (dim=9|id=69|"Boson,Site,n=33"), (dim=1|id=90|"Link,l=33"))
# [34] ((dim=1|id=90|"Link,l=33"), (dim=9|id=323|"Boson,Site,n=34"), (dim=1|id=531|"Link,l=34"))
# [35] ((dim=1|id=531|"Link,l=34"), (dim=9|id=38|"Boson,Site,n=35"), (dim=1|id=111|"Link,l=35"))
# [36] ((dim=1|id=111|"Link,l=35"), (dim=9|id=622|"Boson,Site,n=36"), (dim=1|id=339|"Link,l=36"))
# [37] ((dim=1|id=339|"Link,l=36"), (dim=9|id=672|"Boson,Site,n=37"), (dim=1|id=135|"Link,l=37"))
# [38] ((dim=1|id=135|"Link,l=37"), (dim=9|id=482|"Boson,Site,n=38"), (dim=1|id=135|"Link,l=38"))
# [39] ((dim=1|id=135|"Link,l=38"), (dim=9|id=609|"Boson,Site,n=39"), (dim=1|id=848|"Link,l=39"))
# [40] ((dim=1|id=848|"Link,l=39"), (dim=9|id=581|"Boson,Site,n=40"), (dim=1|id=588|"Link,l=40"))
# [41] ((dim=1|id=588|"Link,l=40"), (dim=9|id=296|"Boson,Site,n=41"), (dim=1|id=292|"Link,l=41"))
# [42] ((dim=1|id=292|"Link,l=41"), (dim=9|id=252|"Boson,Site,n=42"), (dim=1|id=176|"Link,l=42"))
# [43] ((dim=1|id=176|"Link,l=42"), (dim=9|id=809|"Boson,Site,n=43"), (dim=1|id=362|"Link,l=43"))
# [44] ((dim=1|id=362|"Link,l=43"), (dim=9|id=891|"Boson,Site,n=44"), (dim=1|id=136|"Link,l=44"))
# [45] ((dim=1|id=136|"Link,l=44"), (dim=9|id=145|"Boson,Site,n=45"), (dim=1|id=829|"Link,l=45"))
# [46] ((dim=1|id=829|"Link,l=45"), (dim=9|id=680|"Boson,Site,n=46"), (dim=1|id=227|"Link,l=46"))
# [47] ((dim=1|id=227|"Link,l=46"), (dim=9|id=221|"Boson,Site,n=47"), (dim=1|id=308|"Link,l=47"))
# [48] ((dim=1|id=308|"Link,l=47"), (dim=9|id=905|"Boson,Site,n=48"), (dim=1|id=202|"Link,l=48"))
# [49] ((dim=1|id=202|"Link,l=48"), (dim=9|id=25|"Boson,Site,n=49"), (dim=1|id=126|"Link,l=49"))
# [50] ((dim=1|id=126|"Link,l=49"), (dim=9|id=733|"Boson,Site,n=50"), (dim=1|id=704|"Link,l=50"))
# [51] ((dim=1|id=704|"Link,l=50"), (dim=9|id=484|"Boson,Site,n=51"))

# %%
function alpha_i(g::Real, m::Real, i::Real)
    prefactor = 2/sqrt(N) * 1/sqrt(2*om_i[i])
    sumterms = exp(im*(m)*om_i[i])*sin(2pi*(m)*((i-1) + 1/2)/N)
    return g*prefactor*sumterms
end
# Out:
# alpha_i (generic function with 1 method)

# %%
function MakeMPO(g::Real)
    OS = OpSum()
    for m in n_0:-1:0
        if m == n_0
            OS += -im*H*n_0
        else
            OS += im*H
        end
        for i in 1:N
            OS += alpha_i(g, m, i), "a†", i
            OS += -1.0*conj(alpha_i(g, m, i)), "a", i
        end
    end

    FinalMPO = MPO(OS, sites)

    return FinalMPO
end
# Out:
# MakeMPO (generic function with 1 method)

# %%
function tebdTEO(g::Real, dt::Real)
    oplist = []
    for i in 1:N
        TE_comp = ITensor()
        for m in n_0:-1:0
            if m == n_0
                TE_comp += -im*(om_i[i]*dp*n_0)/(2pi)*dt * scalar(op("a", sites[i]) * op("a†", sites[i])) * op("Id", sites[i]) - im*(om_i[i]*dp*n_0)/(2pi)*dt*(1/2)*(2pi/dp) * op("Id", sites[i])
            else
                TE_comp += im*(om_i[i]*dp)/(2pi)*dt * scalar(op("a", sites[i]) * op("a†", sites[i])) * op("Id", sites[i]) + im*(om_i[i]*dp)/(2pi)*dt*(1/2)*(2pi/dp) * op("Id", sites[i])
            end
            TE_comp += im*alpha_i(g, m, i)*dt * op("a†", sites[i]) - im*conj(alpha_i(g, m, i))*dt * op("a", sites[i])
        end
        push!(oplist, TE_comp)
    end

    #return prod([exp(oplist[i]) for i in 1:N])
    return [exp(oplist[i]) for i in 1:N]
end
# Out:
# tebdTEO (generic function with 1 method)

# %%
analytic_expval_list_gs = [1.000000000000000000e+00, 9.865557042176271718e-01, 9.472976238983812358e-01, 8.853082430513204981e-01,
    8.052779210799475562e-01, 7.129191814793082171e-01, 6.142964870017885159e-01, 5.151799915081223258e-01, 4.205166223965494110e-01,
    3.340800725907865365e-01, 2.583218838640578552e-01, 1.944084112073236059e-01, 1.424007008780938943e-01, 1.015201911120904854e-01,
    7.044269298223648779e-02, 4.757323648633249996e-02, 3.127034479776639314e-02, 2.000533672370481339e-02, 1.245667935233876408e-02,
    7.549217345840305605e-03, 4.452919015901587833e-03, 2.556412241214524143e-03, 1.428434083153741832e-03, 7.768420824287834443e-04,
    4.111956459680043432e-04, 2.118397693979734084e-04, 1.062208339031530286e-04, 5.183882417532081888e-05, 2.462316082823460503e-05,
    1.138349668138776117e-05, 5.122132312901244701e-06]

analytic_expval_list_p1 = [0.000000000000000000e+00, 3.587035179713557106e-03, 1.377718414907865528e-02, 2.897016984672432308e-02,
    4.684678576200373978e-02, 6.480288374306429622e-02, 8.040712917503586854e-02, 9.178444616018294200e-02, 9.785368058944600433e-02,
    9.838969499259510310e-02, 9.392370660358090317e-02, 8.552920699505286994e-02, 7.455703747227974965e-02, 6.238111819219377407e-02,
    5.020026917178475878e-02, 3.891878201702064777e-02, 2.910627707721820390e-02, 2.102121104932483733e-02, 1.467443266032107153e-02,
    9.908847739653099326e-03, 6.476178524606042604e-03, 4.099052700534836467e-03, 2.513735565619241996e-03, 1.494178351570996793e-03,
    8.611623115849693661e-04, 4.813949569981115133e-04, 2.610780898499247380e-04, 1.374031517009649940e-04, 7.018978117427895143e-05,
    3.480853177398786369e-05, 1.676128560270752748e-05]

analytic_expval_list_p1p2 = [0.000000000000000000e+00, 1.304216409220052575e-05, 2.003708214705567331e-04, 9.479983356479464206e-04,
    2.725296793544159952e-03, 5.890448525600532233e-03, 1.052473285941502197e-02, 1.635231316392990811e-02, 2.277042641104392445e-02,
    2.897668216384038237e-02, 3.414988513632086220e-02, 3.762823431235913507e-02, 3.903598649701647133e-02, 3.833132960330908057e-02,
    3.577471158797324025e-02, 3.183873340472712088e-02, 2.709197390609889219e-02, 2.208867164213492232e-02, 1.728702873465781317e-02,
    1.300601890628171227e-02, 9.418740411131618431e-03, 6.572583549271170979e-03, 4.423631841595469447e-03, 2.873903199635304082e-03,
    1.803522323658253088e-03, 1.093945227007180878e-03, 6.416986808993826747e-04, 3.641985789165839266e-04, 2.000801365697943684e-04,
    1.064377596948549136e-04, 5.484838693993118064e-05]
# Out:
# 31-element Vector{Float64}:
#  0.0
#  1.3042164092200526e-5
#  0.00020037082147055673
#  0.0009479983356479464
#  0.00272529679354416
#  0.005890448525600532
#  0.010524732859415022
#  0.016352313163929908
#  0.022770426411043924
#  0.028976682163840382
#  0.03414988513632086
#  0.037628234312359135
#  0.03903598649701647
#  ⋮
#  0.013006018906281712
#  0.009418740411131618
#  0.006572583549271171
#  0.0044236318415954694
#  0.002873903199635304
#  0.001803522323658253
#  0.0010939452270071809
#  0.0006416986808993827
#  0.0003641985789165839
#  0.00020008013656979437
#  0.00010643775969485491
#  5.484838693993118e-5

# %%
g_list = range(0, stop=0.15, length=31)
ITensors.set_warn_order(N)
ITensors.set_warn_order(N)
# Out:
# 51

# %%
exp_val_list_gs = []
exp_val_list_p1 = []
exp_val_list_p1p2 = []
for g in g_list
    Psi = tdvp(MakeMPO(g), dx, psi_gs; nsteps=1, maxdim=500, cutoff=1e-15)
    normalize!(Psi)

    exp_val_gs = abs2(inner(psi_gs, Psi))
    exp_val_p1 = abs2(inner(psi_p1, Psi))
    exp_val_p1p2 = abs2(inner(psi_p1p2, Psi))
    push!(exp_val_list_gs, exp_val_gs)
    push!(exp_val_list_p1, exp_val_p1)
    push!(exp_val_list_p1p2, exp_val_p1p2)
end

# %%
gr()
default(size=(800, 600))
plot(g_list, analytic_expval_list_gs, linewidth=1.8, label="Analytic Calculation", color="blue")
plot!(g_list, analytic_expval_list_p1, linewidth=1.8, label="", color="blue")
plot!(g_list, analytic_expval_list_p1p2, linewidth=1.8, label="", color="blue")

plot!(g_list, exp_val_list_gs, linewidth=1.9, label="TDVP", linestyle=:dash, color="orange")
plot!(g_list, exp_val_list_p1, linewidth=1.9, label="", linestyle=:dash, color="orange")
plot!(g_list, exp_val_list_p1p2, linewidth=1.9, label="", linestyle=:dash, color="orange")

# Add text annotations
annotate!(0.046, 0.5, text("\$X = |\\Omega\\rangle\$", 12))
annotate!(0.042, 0.1205, text("\$X = |10...0\\rangle\$", 10))
annotate!(0.038, 0.045, text("\$X = |10...01\\rangle\$", 10))

# Axis labels with larger font via `guidefont`
xlabel!("\n Coupling Constant, \$g\$", guidefont=font(20))
ylabel!("Transition rate \n \$|\\langle X | \\mathrm{T}[Y_{n}Y_{\\bar{n}}^\\dag] | \\Omega\\rangle|^2\$ \n", guidefont=font(20))

plot!(tickfontsize=12)

# Set margins
plot!(left_margin = 18px)

# Set y-limits
ylims!(0, 1.02)

# Add legend
plot!(legend=:topright, legendfontsize=12, frame=false)

# Enable minor ticks
plot!(minorgrid=true)

#savefig("Transition Rates, N=51 (TDVP)")

# %%
exp_val_list_gs_2 = []
exp_val_list_p1_2 = []
exp_val_list_p1p2_2 = []
dt = dx #n_0*dt = n_0*dx is the total evolution time. But since n_0 is already hardcoded into the operator, we only need to input dt=dx into the time evolution operator function (tebdTEO)
num_steps = 1 #Number of steps in the TEBD algorithm. To reduce trotter error, we want to break down the full application of dt into smaller steps
step_width = dt/num_steps #Width of each step
for g in g_list
    Psi = copy(psi_gs)
    for t_step in 1:num_steps
        for i in 1:N
            Psi = apply(tebdTEO(g, step_width)[i], Psi; maxdim=100, cutoff=1e-15)
        end
    end
    normalize!(Psi)

    exp_val_gs_2 = abs2(inner(psi_gs, Psi))
    exp_val_p1_2 = abs2(inner(psi_p1, Psi))
    exp_val_p1p2_2 = abs2(inner(psi_p1p2, Psi))
    push!(exp_val_list_gs_2, exp_val_gs_2)
    push!(exp_val_list_p1_2, exp_val_p1_2)
    push!(exp_val_list_p1p2_2, exp_val_p1p2_2)
end

# %%
gr()
default(size=(800, 600))
plot(g_list, analytic_expval_list_gs, linewidth=1.8, label="Analytic Calculation", color="blue")
plot!(g_list, analytic_expval_list_p1, linewidth=1.8, label="", color="blue")
plot!(g_list, analytic_expval_list_p1p2, linewidth=1.8, label="", color="blue")

plot!(g_list, exp_val_list_gs_2, linewidth=1.9, label="TEBD", linestyle=:dash, color="red")
plot!(g_list, exp_val_list_p1_2, linewidth=1.9, label="", linestyle=:dash, color="red")
plot!(g_list, exp_val_list_p1p2_2, linewidth=1.9, label="", linestyle=:dash, color="red")

# Add text annotations
annotate!(0.046, 0.5, text("\$X = |\\Omega\\rangle\$", 12))
annotate!(0.042, 0.1205, text("\$X = |10...0\\rangle\$", 10))
annotate!(0.038, 0.045, text("\$X = |10...01\\rangle\$", 10))

# Axis labels with larger font via `guidefont`
xlabel!("\n Coupling Constant, \$g\$", guidefont=font(20))
ylabel!("Transition rate \n \$|\\langle X | \\mathrm{T}[Y_{n}Y_{\\bar{n}}^\\dag] | \\Omega\\rangle|^2\$ \n", guidefont=font(20))

plot!(tickfontsize=12)

# Set margins
plot!(left_margin = 18px)

# Set y-limits
ylims!(0, 1.02)

# Add legend
plot!(legend=:topright, legendfontsize=12, frame=false)

# Enable minor ticks
plot!(minorgrid=true)

#savefig("Transition Rates, N=51 (TEBD)")

# %% [markdown]
# ### N=101

# %%
N = 101 #Number of lattice sites per dimension

n_0 = round(Int, ((N-1)/2)) #Index of thepoint at the center of the lattice.
dp = (2*pi)/(N*dx) #Discrete change in momentum
p_i = range(1/2*dp, stop = dp*(N+1/2), length = (N+1))[1:end-1]

om_i = Float64[] #List of omega values for each lattice site (eq. 12)
for i in 1:N
    push!(om_i, (2/dx)*abs(sin(p_i[i]*dx/2)))
end

H = OpSum() #Evaluate the sum of the pi^2 and phi operators that make up the Hamiltonian
for i in 1:N
    H += (om_i[i]*dp)/(2pi), "a", i, "a†", i
    H += (om_i[i]*dp)/(2pi)*(1/2)*(2pi/dp), "Id", i
end

sites = siteinds("Boson", N; dim=9) #Create ITensor "SFT" sites

psi00000 = MPS(sites, MakeState(Dict()))
psi10000 = MPS(sites, MakeState(Dict(1=>"1")))
psi10001 = MPS(sites, MakeState(Dict(1=>"1", N=>"1")))
# Out:
# MPS
# [1] ((dim=9|id=859|"Boson,Site,n=1"), (dim=1|id=353|"Link,l=1"))
# [2] ((dim=1|id=353|"Link,l=1"), (dim=9|id=230|"Boson,Site,n=2"), (dim=1|id=730|"Link,l=2"))
# [3] ((dim=1|id=730|"Link,l=2"), (dim=9|id=164|"Boson,Site,n=3"), (dim=1|id=679|"Link,l=3"))
# [4] ((dim=1|id=679|"Link,l=3"), (dim=9|id=851|"Boson,Site,n=4"), (dim=1|id=713|"Link,l=4"))
# [5] ((dim=1|id=713|"Link,l=4"), (dim=9|id=255|"Boson,Site,n=5"), (dim=1|id=817|"Link,l=5"))
# [6] ((dim=1|id=817|"Link,l=5"), (dim=9|id=494|"Boson,Site,n=6"), (dim=1|id=736|"Link,l=6"))
# [7] ((dim=1|id=736|"Link,l=6"), (dim=9|id=854|"Boson,Site,n=7"), (dim=1|id=248|"Link,l=7"))
# [8] ((dim=1|id=248|"Link,l=7"), (dim=9|id=139|"Boson,Site,n=8"), (dim=1|id=685|"Link,l=8"))
# [9] ((dim=1|id=685|"Link,l=8"), (dim=9|id=145|"Boson,Site,n=9"), (dim=1|id=348|"Link,l=9"))
# [10] ((dim=1|id=348|"Link,l=9"), (dim=9|id=710|"Boson,Site,n=10"), (dim=1|id=220|"Link,l=10"))
# [11] ((dim=1|id=220|"Link,l=10"), (dim=9|id=509|"Boson,Site,n=11"), (dim=1|id=421|"Link,l=11"))
# [12] ((dim=1|id=421|"Link,l=11"), (dim=9|id=93|"Boson,Site,n=12"), (dim=1|id=331|"Link,l=12"))
# [13] ((dim=1|id=331|"Link,l=12"), (dim=9|id=85|"Boson,Site,n=13"), (dim=1|id=105|"Link,l=13"))
# [14] ((dim=1|id=105|"Link,l=13"), (dim=9|id=390|"Boson,Site,n=14"), (dim=1|id=479|"Link,l=14"))
# [15] ((dim=1|id=479|"Link,l=14"), (dim=9|id=289|"Boson,Site,n=15"), (dim=1|id=747|"Link,l=15"))
# [16] ((dim=1|id=747|"Link,l=15"), (dim=9|id=803|"Boson,Site,n=16"), (dim=1|id=392|"Link,l=16"))
# [17] ((dim=1|id=392|"Link,l=16"), (dim=9|id=754|"Boson,Site,n=17"), (dim=1|id=673|"Link,l=17"))
# [18] ((dim=1|id=673|"Link,l=17"), (dim=9|id=581|"Boson,Site,n=18"), (dim=1|id=536|"Link,l=18"))
# [19] ((dim=1|id=536|"Link,l=18"), (dim=9|id=358|"Boson,Site,n=19"), (dim=1|id=890|"Link,l=19"))
# [20] ((dim=1|id=890|"Link,l=19"), (dim=9|id=642|"Boson,Site,n=20"), (dim=1|id=525|"Link,l=20"))
# [21] ((dim=1|id=525|"Link,l=20"), (dim=9|id=735|"Boson,Site,n=21"), (dim=1|id=807|"Link,l=21"))
# [22] ((dim=1|id=807|"Link,l=21"), (dim=9|id=3|"Boson,Site,n=22"), (dim=1|id=159|"Link,l=22"))
# [23] ((dim=1|id=159|"Link,l=22"), (dim=9|id=70|"Boson,Site,n=23"), (dim=1|id=804|"Link,l=23"))
# [24] ((dim=1|id=804|"Link,l=23"), (dim=9|id=683|"Boson,Site,n=24"), (dim=1|id=259|"Link,l=24"))
# [25] ((dim=1|id=259|"Link,l=24"), (dim=9|id=636|"Boson,Site,n=25"), (dim=1|id=340|"Link,l=25"))
# [26] ((dim=1|id=340|"Link,l=25"), (dim=9|id=773|"Boson,Site,n=26"), (dim=1|id=782|"Link,l=26"))
# [27] ((dim=1|id=782|"Link,l=26"), (dim=9|id=157|"Boson,Site,n=27"), (dim=1|id=629|"Link,l=27"))
# [28] ((dim=1|id=629|"Link,l=27"), (dim=9|id=585|"Boson,Site,n=28"), (dim=1|id=544|"Link,l=28"))
# [29] ((dim=1|id=544|"Link,l=28"), (dim=9|id=117|"Boson,Site,n=29"), (dim=1|id=288|"Link,l=29"))
# [30] ((dim=1|id=288|"Link,l=29"), (dim=9|id=666|"Boson,Site,n=30"), (dim=1|id=209|"Link,l=30"))
# [31] ((dim=1|id=209|"Link,l=30"), (dim=9|id=161|"Boson,Site,n=31"), (dim=1|id=174|"Link,l=31"))
# [32] ((dim=1|id=174|"Link,l=31"), (dim=9|id=63|"Boson,Site,n=32"), (dim=1|id=291|"Link,l=32"))
# [33] ((dim=1|id=291|"Link,l=32"), (dim=9|id=985|"Boson,Site,n=33"), (dim=1|id=771|"Link,l=33"))
# [34] ((dim=1|id=771|"Link,l=33"), (dim=9|id=981|"Boson,Site,n=34"), (dim=1|id=646|"Link,l=34"))
# [35] ((dim=1|id=646|"Link,l=34"), (dim=9|id=649|"Boson,Site,n=35"), (dim=1|id=271|"Link,l=35"))
# [36] ((dim=1|id=271|"Link,l=35"), (dim=9|id=867|"Boson,Site,n=36"), (dim=1|id=653|"Link,l=36"))
# [37] ((dim=1|id=653|"Link,l=36"), (dim=9|id=40|"Boson,Site,n=37"), (dim=1|id=601|"Link,l=37"))
# [38] ((dim=1|id=601|"Link,l=37"), (dim=9|id=280|"Boson,Site,n=38"), (dim=1|id=831|"Link,l=38"))
# [39] ((dim=1|id=831|"Link,l=38"), (dim=9|id=315|"Boson,Site,n=39"), (dim=1|id=325|"Link,l=39"))
# [40] ((dim=1|id=325|"Link,l=39"), (dim=9|id=975|"Boson,Site,n=40"), (dim=1|id=361|"Link,l=40"))
# [41] ((dim=1|id=361|"Link,l=40"), (dim=9|id=726|"Boson,Site,n=41"), (dim=1|id=340|"Link,l=41"))
# [42] ((dim=1|id=340|"Link,l=41"), (dim=9|id=371|"Boson,Site,n=42"), (dim=1|id=755|"Link,l=42"))
# [43] ((dim=1|id=755|"Link,l=42"), (dim=9|id=739|"Boson,Site,n=43"), (dim=1|id=49|"Link,l=43"))
# [44] ((dim=1|id=49|"Link,l=43"), (dim=9|id=389|"Boson,Site,n=44"), (dim=1|id=30|"Link,l=44"))
# [45] ((dim=1|id=30|"Link,l=44"), (dim=9|id=464|"Boson,Site,n=45"), (dim=1|id=966|"Link,l=45"))
# [46] ((dim=1|id=966|"Link,l=45"), (dim=9|id=426|"Boson,Site,n=46"), (dim=1|id=101|"Link,l=46"))
# [47] ((dim=1|id=101|"Link,l=46"), (dim=9|id=129|"Boson,Site,n=47"), (dim=1|id=935|"Link,l=47"))
# [48] ((dim=1|id=935|"Link,l=47"), (dim=9|id=436|"Boson,Site,n=48"), (dim=1|id=293|"Link,l=48"))
# [49] ((dim=1|id=293|"Link,l=48"), (dim=9|id=199|"Boson,Site,n=49"), (dim=1|id=34|"Link,l=49"))
# [50] ((dim=1|id=34|"Link,l=49"), (dim=9|id=749|"Boson,Site,n=50"), (dim=1|id=912|"Link,l=50"))
# [51] ((dim=1|id=912|"Link,l=50"), (dim=9|id=399|"Boson,Site,n=51"), (dim=1|id=17|"Link,l=51"))
# [52] ((dim=1|id=17|"Link,l=51"), (dim=9|id=503|"Boson,Site,n=52"), (dim=1|id=948|"Link,l=52"))
# [53] ((dim=1|id=948|"Link,l=52"), (dim=9|id=471|"Boson,Site,n=53"), (dim=1|id=569|"Link,l=53"))
# [54] ((dim=1|id=569|"Link,l=53"), (dim=9|id=546|"Boson,Site,n=54"), (dim=1|id=785|"Link,l=54"))
# [55] ((dim=1|id=785|"Link,l=54"), (dim=9|id=614|"Boson,Site,n=55"), (dim=1|id=472|"Link,l=55"))
# [56] ((dim=1|id=472|"Link,l=55"), (dim=9|id=984|"Boson,Site,n=56"), (dim=1|id=505|"Link,l=56"))
# [57] ((dim=1|id=505|"Link,l=56"), (dim=9|id=848|"Boson,Site,n=57"), (dim=1|id=217|"Link,l=57"))
# [58] ((dim=1|id=217|"Link,l=57"), (dim=9|id=909|"Boson,Site,n=58"), (dim=1|id=197|"Link,l=58"))
# [59] ((dim=1|id=197|"Link,l=58"), (dim=9|id=138|"Boson,Site,n=59"), (dim=1|id=892|"Link,l=59"))
# [60] ((dim=1|id=892|"Link,l=59"), (dim=9|id=857|"Boson,Site,n=60"), (dim=1|id=882|"Link,l=60"))
# [61] ((dim=1|id=882|"Link,l=60"), (dim=9|id=890|"Boson,Site,n=61"), (dim=1|id=930|"Link,l=61"))
# [62] ((dim=1|id=930|"Link,l=61"), (dim=9|id=929|"Boson,Site,n=62"), (dim=1|id=834|"Link,l=62"))
# [63] ((dim=1|id=834|"Link,l=62"), (dim=9|id=296|"Boson,Site,n=63"), (dim=1|id=932|"Link,l=63"))
# [64] ((dim=1|id=932|"Link,l=63"), (dim=9|id=186|"Boson,Site,n=64"), (dim=1|id=309|"Link,l=64"))
# [65] ((dim=1|id=309|"Link,l=64"), (dim=9|id=393|"Boson,Site,n=65"), (dim=1|id=565|"Link,l=65"))
# [66] ((dim=1|id=565|"Link,l=65"), (dim=9|id=76|"Boson,Site,n=66"), (dim=1|id=317|"Link,l=66"))
# [67] ((dim=1|id=317|"Link,l=66"), (dim=9|id=502|"Boson,Site,n=67"), (dim=1|id=725|"Link,l=67"))
# [68] ((dim=1|id=725|"Link,l=67"), (dim=9|id=323|"Boson,Site,n=68"), (dim=1|id=277|"Link,l=68"))
# [69] ((dim=1|id=277|"Link,l=68"), (dim=9|id=56|"Boson,Site,n=69"), (dim=1|id=192|"Link,l=69"))
# [70] ((dim=1|id=192|"Link,l=69"), (dim=9|id=646|"Boson,Site,n=70"), (dim=1|id=440|"Link,l=70"))
# [71] ((dim=1|id=440|"Link,l=70"), (dim=9|id=651|"Boson,Site,n=71"), (dim=1|id=97|"Link,l=71"))
# [72] ((dim=1|id=97|"Link,l=71"), (dim=9|id=882|"Boson,Site,n=72"), (dim=1|id=891|"Link,l=72"))
# [73] ((dim=1|id=891|"Link,l=72"), (dim=9|id=167|"Boson,Site,n=73"), (dim=1|id=568|"Link,l=73"))
# [74] ((dim=1|id=568|"Link,l=73"), (dim=9|id=425|"Boson,Site,n=74"), (dim=1|id=687|"Link,l=74"))
# [75] ((dim=1|id=687|"Link,l=74"), (dim=9|id=185|"Boson,Site,n=75"), (dim=1|id=49|"Link,l=75"))
# [76] ((dim=1|id=49|"Link,l=75"), (dim=9|id=60|"Boson,Site,n=76"), (dim=1|id=408|"Link,l=76"))
# [77] ((dim=1|id=408|"Link,l=76"), (dim=9|id=97|"Boson,Site,n=77"), (dim=1|id=445|"Link,l=77"))
# [78] ((dim=1|id=445|"Link,l=77"), (dim=9|id=160|"Boson,Site,n=78"), (dim=1|id=282|"Link,l=78"))
# [79] ((dim=1|id=282|"Link,l=78"), (dim=9|id=585|"Boson,Site,n=79"), (dim=1|id=885|"Link,l=79"))
# [80] ((dim=1|id=885|"Link,l=79"), (dim=9|id=283|"Boson,Site,n=80"), (dim=1|id=727|"Link,l=80"))
# [81] ((dim=1|id=727|"Link,l=80"), (dim=9|id=198|"Boson,Site,n=81"), (dim=1|id=897|"Link,l=81"))
# [82] ((dim=1|id=897|"Link,l=81"), (dim=9|id=619|"Boson,Site,n=82"), (dim=1|id=111|"Link,l=82"))
# [83] ((dim=1|id=111|"Link,l=82"), (dim=9|id=650|"Boson,Site,n=83"), (dim=1|id=330|"Link,l=83"))
# [84] ((dim=1|id=330|"Link,l=83"), (dim=9|id=858|"Boson,Site,n=84"), (dim=1|id=49|"Link,l=84"))
# [85] ((dim=1|id=49|"Link,l=84"), (dim=9|id=301|"Boson,Site,n=85"), (dim=1|id=770|"Link,l=85"))
# [86] ((dim=1|id=770|"Link,l=85"), (dim=9|id=286|"Boson,Site,n=86"), (dim=1|id=790|"Link,l=86"))
# [87] ((dim=1|id=790|"Link,l=86"), (dim=9|id=149|"Boson,Site,n=87"), (dim=1|id=397|"Link,l=87"))
# [88] ((dim=1|id=397|"Link,l=87"), (dim=9|id=438|"Boson,Site,n=88"), (dim=1|id=558|"Link,l=88"))
# [89] ((dim=1|id=558|"Link,l=88"), (dim=9|id=706|"Boson,Site,n=89"), (dim=1|id=309|"Link,l=89"))
# [90] ((dim=1|id=309|"Link,l=89"), (dim=9|id=91|"Boson,Site,n=90"), (dim=1|id=484|"Link,l=90"))
# [91] ((dim=1|id=484|"Link,l=90"), (dim=9|id=266|"Boson,Site,n=91"), (dim=1|id=528|"Link,l=91"))
# [92] ((dim=1|id=528|"Link,l=91"), (dim=9|id=151|"Boson,Site,n=92"), (dim=1|id=266|"Link,l=92"))
# [93] ((dim=1|id=266|"Link,l=92"), (dim=9|id=50|"Boson,Site,n=93"), (dim=1|id=888|"Link,l=93"))
# [94] ((dim=1|id=888|"Link,l=93"), (dim=9|id=535|"Boson,Site,n=94"), (dim=1|id=843|"Link,l=94"))
# [95] ((dim=1|id=843|"Link,l=94"), (dim=9|id=168|"Boson,Site,n=95"), (dim=1|id=701|"Link,l=95"))
# [96] ((dim=1|id=701|"Link,l=95"), (dim=9|id=554|"Boson,Site,n=96"), (dim=1|id=716|"Link,l=96"))
# [97] ((dim=1|id=716|"Link,l=96"), (dim=9|id=356|"Boson,Site,n=97"), (dim=1|id=278|"Link,l=97"))
# [98] ((dim=1|id=278|"Link,l=97"), (dim=9|id=245|"Boson,Site,n=98"), (dim=1|id=550|"Link,l=98"))
# [99] ((dim=1|id=550|"Link,l=98"), (dim=9|id=274|"Boson,Site,n=99"), (dim=1|id=774|"Link,l=99"))
# [100] ((dim=1|id=774|"Link,l=99"), (dim=9|id=818|"Boson,Site,n=100"), (dim=1|id=180|"Link,l=100"))
# [101] ((dim=1|id=180|"Link,l=100"), (dim=9|id=76|"Boson,Site,n=101"))

# %%
g_list = range(0, stop=0.06, length=31)
ITensors.set_warn_order(N)
ITensors.set_warn_order(N)
# Out:
# 101

# %%
exp_val_list_00000 = []
exp_val_list_10000 = []
exp_val_list_10001 = []
for g in g_list
    Psi = tdvp(MakeMPO(g), dx, psi00000; nsteps=1, maxdim=300, cutoff=1e-15)
    normalize!(Psi)

    exp_val_00000 = abs2(inner(psi00000, Psi))
    exp_val_10000 = abs2(inner(psi10000, Psi))
    exp_val_10001 = abs2(inner(psi10001, Psi))
    push!(exp_val_list_00000, exp_val_00000)
    push!(exp_val_list_10000, exp_val_10000)
    push!(exp_val_list_10001, exp_val_10001)
end

# %%
exp_val_list_00000_2 = []
exp_val_list_10000_2 = []
exp_val_list_10001_2 = []
dt = dx #n_0*dt = n_0*dx is the total evolution time. But since n_0 is already hardcoded into the operator, we only need to input dt=dx into the time evolution operator function (tebdTEO)
num_steps = 1 #Number of steps in the TEBD algorithm. To reduce trotter error, we want to break down the full application of dt into smaller steps
step_width = dt/num_steps #Width of each step
for g in g_list
    Psi = copy(psi00000)
    for t_step in 1:num_steps
        for i in 1:N
            Psi = apply(tebdTEO(g, step_width)[i], Psi; maxdim=100, cutoff=1e-15)
        end
    end
    normalize!(Psi)

    exp_val_00000_2 = abs2(inner(psi00000, Psi))
    exp_val_10000_2 = abs2(inner(psi10000, Psi))
    exp_val_10001_2 = abs2(inner(psi10001, Psi))
    push!(exp_val_list_00000_2, exp_val_00000_2)
    push!(exp_val_list_10000_2, exp_val_10000_2)
    push!(exp_val_list_10001_2, exp_val_10001_2)
end

# %%
analytic_00000 = [1.000000000000000000e+00, 9.908232690580748292e-01, 9.637952664909003042e-01, 9.203770382643921000e-01,
 8.628576543282623357e-01, 7.941543723344067773e-01, 7.175680628197959043e-01, 6.365223615483031061e-01,
 5.543149913457101619e-01, 4.739057492787654979e-01, 3.977587345319131829e-01, 3.277478621707901052e-01,
 2.651260517527713745e-01, 2.105510132192215111e-01, 1.641552063982073262e-01, 1.256447602092179150e-01,
 9.441184759630143197e-02, 6.964677416800643672e-02, 5.043916749037805070e-02, 3.586139736730002692e-02,
 2.503104039189176996e-02, 1.715232465794841801e-02, 1.153876876487479157e-02, 7.620585614950455174e-03,
 4.940940425370784171e-03, 3.145019067826486815e-03, 1.965302210993053692e-03, 1.205668174349711769e-03,
 7.261371327676177179e-04, 4.293405313279478452e-04, 2.492169216752571320e-04]

analytic_10000 = [0.000000000000000000e+00, 2.260610607271971127e-03, 8.795779714536123076e-03, 1.889895750663164731e-02,
 3.149841513584319963e-02, 4.529752817617135885e-02, 5.893796895637732486e-02, 7.116055215259625699e-02,
 8.094055201733692251e-02, 8.758032654955788532e-02, 9.075055486663341497e-02, 9.048046038224337451e-02,
 8.710527581914363771e-02, 8.118459044467558894e-02, 7.340747682520110118e-02, 6.449951719250751614e-02,
 5.514371561822246220e-02, 4.592280556378730560e-02, 3.728571570543796898e-02, 2.953683615438552554e-02,
 2.284380562630774006e-02, 1.725802690344005116e-02, 1.274190596606940631e-02, 9.197580179584077115e-03,
 6.493243130391545756e-03, 4.484694500286589072e-03, 3.031137255717954778e-03, 2.005325559409066455e-03,
 1.298865772584815960e-03, 8.238107390298614113e-04, 5.117402778274473575e-04]

analytic_10001 = [0.000000000000000000e+00, 5.157691060857568287e-06, 8.027196592106829989e-05, 3.880698670090713628e-04,
 1.149842214521814687e-03, 2.583711845392962919e-03, 4.840912471846199432e-03, 7.955453709976306395e-03,
 1.181886303483585011e-02, 1.618531450652484563e-02, 2.070517249179603531e-02, 2.497869446579800701e-02,
 2.861781792233743585e-02, 3.130328192155173300e-02, 3.282660216557857502e-02, 3.311071397756007451e-02,
 3.220813329684790727e-02, 3.027999639670549484e-02, 2.756240169768733525e-02, 2.432768252378595189e-02,
 2.084769339677796859e-02, 1.736438054545794141e-02, 1.407049321781910813e-02, 1.110091604953737654e-02,
 8.533235117323368160e-03, 6.395027924202789128e-03, 4.675002659442777445e-03, 3.335354357668263506e-03,
 2.323324643600392907e-03, 1.580712940475981123e-03, 1.050803894817992383e-03]
# Out:
# 31-element Vector{Float64}:
#  0.0
#  5.157691060857568e-6
#  8.02719659210683e-5
#  0.00038806986700907136
#  0.0011498422145218147
#  0.002583711845392963
#  0.004840912471846199
#  0.007955453709976306
#  0.01181886303483585
#  0.016185314506524846
#  0.020705172491796035
#  0.024978694465798007
#  0.028617817922337436
#  ⋮
#  0.024327682523785952
#  0.02084769339677797
#  0.01736438054545794
#  0.014070493217819108
#  0.011100916049537377
#  0.008533235117323368
#  0.006395027924202789
#  0.0046750026594427774
#  0.0033353543576682635
#  0.002323324643600393
#  0.0015807129404759811
#  0.0010508038948179924

# %%
gr()
default(size=(800, 600))
plot(g_list, analytic_00000, linewidth=1.8, label="Analytic Calculation", color="blue")
plot!(g_list, analytic_10000, linewidth=1.8, label="", color="blue")
plot!(g_list, analytic_10001, linewidth=1.8, label="", color="blue")

plot!(g_list, exp_val_list_00000, linewidth=1.9, label="TDVP", linestyle=:dash, color="orange")
plot!(g_list, exp_val_list_10000, linewidth=1.9, label="", linestyle=:dash, color="orange")
plot!(g_list, exp_val_list_10001, linewidth=1.9, label="", linestyle=:dash, color="orange")

# Add text annotations
annotate!(0.0215, 0.5, text("\$X = |\\Omega\\rangle\$", 12))
annotate!(0.020, 0.115, text("\$X = |10...0\\rangle\$", 10))
annotate!(0.022, 0.045, text("\$X = |10...01\\rangle\$", 10))

# Axis labels with larger font via `guidefont`
xlabel!("\n Coupling Constant, \$g\$", guidefont=font(20))
ylabel!("Transition rate \n \$|\\langle X | \\mathrm{T}[Y_{n}Y_{\\bar{n}}^\\dag] | \\Omega\\rangle|^2\$ \n", guidefont=font(20))

plot!(tickfontsize=12)

# Set margins
plot!(left_margin = 18px)

# Set y-limits
ylims!(0, 1.02)

# Add legend
plot!(legend=:topright, legendfontsize=12, frame=false)

# Enable minor ticks
plot!(minorgrid=true)

#savefig("Transition Rates, N=101 (TDVP)")

# %%
gr()
default(size=(800, 600))
plot(g_list, analytic_00000, linewidth=1.8, label="Analytic Calculation", color="blue")
plot!(g_list, analytic_10000, linewidth=1.8, label="", color="blue")
plot!(g_list, analytic_10001, linewidth=1.8, label="", color="blue")

plot!(g_list, exp_val_list_00000_2, linewidth=1.9, label="TEBD", linestyle=:dash, color="red")
plot!(g_list, exp_val_list_10000_2, linewidth=1.9, label="", linestyle=:dash, color="red")
plot!(g_list, exp_val_list_10001_2, linewidth=1.9, label="", linestyle=:dash, color="red")

# Add text annotations
annotate!(0.0215, 0.5, text("\$X = |\\Omega\\rangle\$", 12))
annotate!(0.020, 0.115, text("\$X = |10...0\\rangle\$", 10))
annotate!(0.022, 0.045, text("\$X = |10...01\\rangle\$", 10))

# Axis labels with larger font via `guidefont`
xlabel!("\n Coupling Constant, \$g\$", guidefont=font(20))
ylabel!("Transition rate \n \$|\\langle X | \\mathrm{T}[Y_{n}Y_{\\bar{n}}^\\dag] | \\Omega\\rangle|^2\$ \n", guidefont=font(20))

plot!(tickfontsize=12)

# Set margins
plot!(left_margin = 18px)

# Set y-limits
ylims!(0, 1.02)

# Add legend
plot!(legend=:topright, legendfontsize=12, frame=false)

# Enable minor ticks
plot!(minorgrid=true)

#savefig("Transition Rates, N=101 (TEBD)")
